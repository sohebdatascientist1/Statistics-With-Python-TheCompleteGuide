# %% [markdown]
# <a href="https://colab.research.google.com/github/sohebdatascientist1/Statistics-With-Python-TheCompleteGuide/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Bank Customer Churn Prediction.csv")

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.drop(columns=['customer_id'],inplace=True)

# %%
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
df['country'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: country, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: gender, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
pd.get_dummies(df,columns=['country','gender'],drop_first=True)
# Out:
#       credit_score  age  tenure    balance  products_number  credit_card  \
# 0              619   42       2       0.00                1            1
# 1              608   41       1   83807.86                1            0
# 2              502   42       8  159660.80                3            1
# 3              699   39       1       0.00                2            0
# 4              850   43       2  125510.82                1            1
# ...            ...  ...     ...        ...              ...          ...
# 9995           771   39       5       0.00                2            1
# 9996           516   35      10   57369.61                1            1
# 9997           709   36       7       0.00                1            0
# 9998           772   42       3   75075.31                2            1
# 9999           792   28       4  130142.79                1            1
#
#       active_member  estimated_salary  churn  country_Germany  country_Spain  \
# ...

# %%
df=pd.get_dummies(df,columns=['country','gender'],drop_first=True)

# %%
df.drop(['churn'],axis=1)
# Out:
#       credit_score  age  tenure    balance  products_number  credit_card  \
# 0              619   42       2       0.00                1            1
# 1              608   41       1   83807.86                1            0
# 2              502   42       8  159660.80                3            1
# 3              699   39       1       0.00                2            0
# 4              850   43       2  125510.82                1            1
# ...            ...  ...     ...        ...              ...          ...
# 9995           771   39       5       0.00                2            1
# 9996           516   35      10   57369.61                1            1
# 9997           709   36       7       0.00                1            0
# 9998           772   42       3   75075.31                2            1
# 9999           792   28       4  130142.79                1            1
#
#       active_member  estimated_salary  country_Germany  country_Spain  \
# ...

# %%
X=df.drop(['churn'],axis=1)

# %%
y=df['churn']

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
len(X.columns)
# Out:
# 11

# %%
from keras.api._v2.keras import activations
model=Sequential()
model.add(Dense(11,activation='sigmoid',input_dim=11))##input layer
model.add(Dense(11,activation='sigmoid'))## hidden layer
model.add(Dense(1,activation='sigmoid'))## output layer

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train_tf=scaler.fit_transform(X_train_tf)
X_test_tf=scaler.transform(X_test_tf)

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5047 - accuracy: 0.7960
# Epoch 2/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5047 - accuracy: 0.7960
# Epoch 3/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5065 - accuracy: 0.7960
# Epoch 4/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.7960
# Epoch 5/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.7960
# Epoch 6/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7960
# Epoch 7/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7960
# Epoch 8/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.7960
# Epoch 9/50
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7960
# Epoch 10/50
# ...

# %%
y_pred=model.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %%
y_pred=y_pred.argmax(axis=-1)

# %%
y_pred=model.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred
# Out:
# array([[0.19619425],
#        [0.19619425],
#        [0.23663014],
#        ...,
#        [0.23663014],
#        [0.2720978 ],
#        [0.19619425]], dtype=float32)

# %%
y_pred.argmax(axis=-1)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7975
